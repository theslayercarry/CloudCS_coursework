# %%
import pandas as pd
from scipy.stats import randint, uniform
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer

# %% [markdown]
# Загружаем датасет и создаём датафрейм:

# %%
df = pd.read_csv('../data/student_performance_finalscore.csv')

# %%
df
# Out:
#      Student_ID  Age      Gender  Hours_Studied  Attendance  Sleep_Hours  \
# 0      STU00001   17      Female           8.20        80.0          7.3
# 1      STU00002   22        Male           4.07        69.2          7.9
# 2      STU00003   23      Female           5.07        74.2          6.7
# 3      STU00004   22      Female           5.82        82.5          3.7
# 4      STU00005   21        Male           3.42        90.8          7.4
# ...         ...  ...         ...            ...         ...          ...
# 7995   STU07996   18      Female           6.45        93.6          9.7
# 7996   STU07997   20  Non-Binary           0.80        94.4          7.6
# 7997   STU07998   19      Female           3.76        96.4          6.8
# 7998   STU07999   20      Female           3.87        79.2          8.2
# 7999   STU08000   23      Female           6.87        74.5          4.9
#
#       Stress_Level  Screen_Time  Previous_GPA Part_Time_Job Study_Method  \
# ...

# %% [markdown]
# Проверим количество пропусков в датафрейме:

# %%
df.isna().sum()
# Out:
# Student_ID                    0
# Age                           0
# Gender                        0
# Hours_Studied                 0
# Attendance                    0
# Sleep_Hours                   0
# Stress_Level                  0
# Screen_Time                   0
# Previous_GPA                  0
# Part_Time_Job                 0
# Study_Method                  0
# Diet_Quality                  0
# Internet_Quality              0
# Extracurricular               0
# Tutoring_Sessions_Per_Week    0
# Family_Income_Level           0
# Exam_Anxiety_Score            0
# Final_Score                   0
# dtype: int64

# %% [markdown]
# Рассмотрим статистические показатели для признаков датасета:

# %%
df.describe()
# Out:
#                Age  Hours_Studied   Attendance  Sleep_Hours  Stress_Level  \
# count  8000.000000    8000.000000  8000.000000  8000.000000   8000.000000
# mean     20.494375       4.983845    79.933375     6.989125      5.014175
# std       2.285962       1.951715     9.656594     1.192898      1.940126
# min      17.000000       0.020000    43.300000     3.000000      1.000000
# 25%      18.000000       3.680000    73.400000     6.200000      3.700000
# 50%      20.500000       4.980000    80.100000     7.000000      5.000000
# 75%      22.000000       6.312500    86.600000     7.800000      6.300000
# max      24.000000      12.000000   100.000000    10.000000     10.000000
#
#        Screen_Time  Previous_GPA  Tutoring_Sessions_Per_Week  \
# count  8000.000000   8000.000000                 8000.000000
# mean      4.024525      2.992408                    1.700625
# std       1.481908      0.489530                    1.112836
# ...

# %% [markdown]
# Выполним предобработку данных:
# 1) отфильтруем наблюдения по условию (уберём записи, в которых Gender = 'Non-Binary');
# 2) удалим наименее содержательные признаки (ID студента, Внеклассную деятельность, Ежедневный рацион питания и метку);
# 3) разделим данные на признаки (X) и целевую переменную (y).

# %%
df.head(15)
# Out:
#    Student_ID  Age      Gender  Hours_Studied  Attendance  Sleep_Hours  \
# 0    STU00001   17      Female           8.20        80.0          7.3
# 1    STU00002   22        Male           4.07        69.2          7.9
# 2    STU00003   23      Female           5.07        74.2          6.7
# 3    STU00004   22      Female           5.82        82.5          3.7
# 4    STU00005   21        Male           3.42        90.8          7.4
# 5    STU00006   22      Female           5.00        82.7          6.5
# 6    STU00007   17        Male           5.00        78.9          5.0
# 7    STU00008   19        Male           1.49        77.4          6.0
# 8    STU00009   21      Female           7.04        95.6          6.7
# 9    STU00010   19      Female           6.20        71.9          6.4
# 10   STU00011   21      Female           3.75        75.4          6.7
# 11   STU00012   19        Male           4.66        83.5          7.1
# ...

# %%
filtered_df = df[df['Gender'] != 'Non-Binary']

# %%
X = filtered_df.drop(columns=['Student_ID', 'Extracurricular', 'Diet_Quality', 'Final_Score'])

# %%
X
# Out:
#       Age  Gender  Hours_Studied  Attendance  Sleep_Hours  Stress_Level  \
# 0      17  Female           8.20        80.0          7.3           2.3
# 1      22    Male           4.07        69.2          7.9           3.6
# 2      23  Female           5.07        74.2          6.7           2.6
# 3      22  Female           5.82        82.5          3.7           3.3
# 4      21    Male           3.42        90.8          7.4           7.0
# ...   ...     ...            ...         ...          ...           ...
# 7994   24  Female           1.09        76.6          8.5           2.3
# 7995   18  Female           6.45        93.6          9.7           5.4
# 7997   19  Female           3.76        96.4          6.8           6.9
# 7998   20  Female           3.87        79.2          8.2           8.2
# 7999   23  Female           6.87        74.5          4.9           2.0
#
#       Screen_Time  Previous_GPA Part_Time_Job Study_Method Internet_Quality  \
# ...

# %%
y = filtered_df['Final_Score']

# %%
X.shape
# Out:
# (7716, 14)

# %%
y.shape
# Out:
# (7716,)

# %%
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size = 0.3, random_state = 54)

# %% [markdown]
# Рассмотрим получившиеся размерности обучающей и тестовой выборок:

# %%
X_train.shape
# Out:
# (5401, 14)

# %%
X_test.shape
# Out:
# (2315, 14)

# %% [markdown]
# Перед написанием конвейера обработки данных (Pipeline) необходимо разделить признаки на категориальные и числовые:
#
# 1) В рассматриваемом датасете категориальные признаки делятся на номинальные (Gender, Study_Method), порядковые (Internet_Quality, Family_Income_Level) и бинарные (Part_Time_Job). Для порядковых признаков применяется OrdinalEncoder, поскольку между их значениями существует естественный порядок. Для номинальных и бинарных признаков используется OneHotEncoder, так как между категориями отсутствует упорядоченность.
# 2) Для модели RandomForestRegressor масштабирование числовых признаков не применяется, поскольку деревья решений и ансамбли на их основе не чувствительны к масштабу данных.

# %%
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold, RandomizedSearchCV, GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# Определим количество уникальных значений в порядковых признаках Internet_Quality и Family_Income_Level.

# %%
df['Internet_Quality'].unique()
# Out:
# array(['Average', 'Good', 'Excellent', 'Poor'], dtype=object)

# %%
df['Family_Income_Level'].unique()
# Out:
# array(['High', 'Middle', 'Low'], dtype=object)

# %% [markdown]
# Приступим к созданию конвейеров:

# %%
ohe_features = ['Gender', 'Study_Method', 'Part_Time_Job']

ohe_transformer = Pipeline(
    steps = [
        ('impute', SimpleImputer(strategy = 'most_frequent')),
        ('one-hot-encoder', OneHotEncoder(handle_unknown = 'ignore', sparse_output = False, drop='first')),
    ]
)

# %%
ord_features = ['Internet_Quality', 'Family_Income_Level']

ord_transformer = Pipeline(
    steps = [
        ('impute', SimpleImputer(strategy = 'most_frequent')),
        ('ordinal-encoder', OrdinalEncoder(categories = [
            ['Poor', 'Average', 'Good', 'Excellent'],
            ['Low', 'Middle', 'High']], 
            handle_unknown = 'use_encoded_value',
            unknown_value = -1)),
    ]
)

# %%
num_features = ['Age', 'Hours_Studied', 'Attendance', 'Sleep_Hours', 'Stress_Level', 'Screen_Time', 'Previous_GPA', 'Tutoring_Sessions_Per_Week', 'Exam_Anxiety_Score']

num_transformer = Pipeline(
    steps = [
        ('impute', SimpleImputer(strategy = 'mean')),
        #('scale', StandardScaler()),
    ]
)

# %% [markdown]
# Объединяем наши конвейеры:

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ('numeric', num_transformer, num_features),
        ('cat_ordinal',ord_transformer, ord_features),
        ('cat_onehot', ohe_transformer, ohe_features),
    ],
    remainder = 'drop',
    n_jobs = -1 #чтобы задействовать все ядра CPU
)

# %% [markdown]
# Рассматриваемые модели:

# %%
rf = RandomForestRegressor()

# %% [markdown]
# Итоговый конвейер:

# %%
pipefinal = Pipeline([
    ('preprocessor', preprocessor),
    ('model', rf)
])

# %% [markdown]
# Настройка гиперпараметров:

# %%
kf = KFold(n_splits = 15, shuffle = True, random_state = 13)

# %%
param_dist = {
    'model__n_estimators': [100, 200, 300, 500],
    'model__max_depth': [8, 10, 15],
    'model__min_samples_split': [5, 10, 15],
    'model__min_samples_leaf': [2, 4, 6]
}

# %%
scoring = {
    'MAE': 'neg_mean_absolute_error',
    'MSE': 'neg_mean_squared_error',
    'R2': 'r2'
}

# %%
random_cv = RandomizedSearchCV(
    estimator=pipefinal,
    param_distributions=param_dist,
    n_iter=20,
    cv=kf,
    scoring=scoring,
    refit='MSE',
    random_state=42,
    n_jobs=-1
)

# %%
random_cv.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=15, random_state=13, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(n_jobs=-1,
#                                                                 transformers=[('numeric',
#                                                                                Pipeline(steps=[('impute',
#                                                                                                 SimpleImputer())]),
#                                                                                ['Age',
#                                                                                 'Hours_Studied',
#                                                                                 'Attendance',
#                                                                                 'Sleep_Hours',
# ...

# %%
random_cv.best_params_
# Out:
# {'model__n_estimators': 500,
#  'model__min_samples_split': 10,
#  'model__min_samples_leaf': 2,
#  'model__max_depth': 15}

# %%
random_cv.best_estimator_
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('numeric',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer())]),
#                                                   ['Age', 'Hours_Studied',
#                                                    'Attendance', 'Sleep_Hours',
#                                                    'Stress_Level',
#                                                    'Screen_Time',
#                                                    'Previous_GPA',
#                                                    'Tutoring_Sessions_Per_Week',
#                                                    'Exam_Anxiety_Score']),
#                                                  ('cat_ordinal',
#                                                   Pipeline(steps=[('impute',
# ...

# %%
model = random_cv.best_estimator_

# %%
y_pred = model.predict(X_test)

# %%
MSE = mean_squared_error(y_test, y_pred)
MAE = mean_absolute_error(y_test, y_pred)

# %%
print(f"MSE - {MSE}")
print(f"MAE - {MAE}")
# Out:
# MSE - 48.92405034339636
# MAE - 5.481078521776955

# %%
model.score(X_test, y_test)
# Out:
# 0.7027277388807026

# %%
model.score(X_train, y_train)
# Out:
# 0.8947467578993171

# %% [markdown]
# Сохраняем модель:

# %%
import joblib

# %%
joblib.dump (model, "../models/model_pipeline.pkl")
# Out:
# ['../models/model_pipeline.pkl']
